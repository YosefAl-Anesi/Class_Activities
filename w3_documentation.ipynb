# %% [markdown]
# # Week 3 Documentation
# ## 1. Components
# * **Inputs:** Quiz_1, Quiz_2, Quiz_3, Choice
# * **Process:** Calculate average = (Quiz_1 + Quiz_2 + Quiz_3) / 3; Check if average >= 50
# * **Output:** Average mark, Pass/Fail status
#
# ## 2. Algorithm Structures
# * **Sequence:** Line-by-line execution of inputs and math calculations.
# * **Selection:** If/Else statement checking the passing grade.
# * **Iteration:** While loop allowing multiple entries.
